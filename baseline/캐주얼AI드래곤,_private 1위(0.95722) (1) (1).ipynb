# %% [markdown]
# # 농업 환경 변화에 따른 작물 병해 진단 AI 경진대회
#
# ## 개발 환경
# "colab(Linux)"
#
# ## 라이브러리 버전
# * python==3.7.12
# * albumentations==1.1.0
# * numpy==1.19.5
# * pandas==1.3.5
# * cv2==4.1.2
# * sklearn==1.0.2
# * json==2.0.9
# * torch==1.10.0+cu111
# * timm==0.5.4
# * transformers==4.16.2
#
# ## 실행 방법
# ### 데이터 경로
# - 해당 대회에서 주어진 train.zip, test.zip 파일을 코랩에 압축풀기
#
#
# ### 훈련 데이터 전처리와 모델 학습
# - train.ipynb 실행
#
# ### 추론
# - inference.ipynb 실행
